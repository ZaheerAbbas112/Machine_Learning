# %% [markdown]
# # Random Forest Model

# %%
# load sample data set
import pandas as pd
import numpy as np
import seaborn as sns
df = sns.load_dataset('iris')
df.head(108)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
#
# [108 rows x 5 columns]

# %%
x = df.iloc[: , :-1]
y = df.iloc[: , -1:]

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100) 
model.fit(x,y)
model.predict([[5,4,2,6]])
# Out:
# C:\Users\malik zaheer abbas\AppData\Local\Temp\ipykernel_11876\3588317660.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# C:\Users\malik zaheer abbas\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100) 
model.fit(x,y)
model.predict([[2,4,2,6]])
# Out:
# C:\Users\malik zaheer abbas\AppData\Local\Temp\ipykernel_11876\546401719.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# C:\Users\malik zaheer abbas\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
 from sklearn.model_selection import train_test_split
 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

 predictions = model.predict(x_test)
 predictions
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'virginica', 'setosa', 'setosa', 'setosa', 'virginica',
#        'virginica', 'virginica', 'setosa', 'versicolor', 'virginica',
#        'versicolor', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'setosa'], dtype=object)

# %%
# accuracy test
score = model.score(x_test, y_test)
print('The accuracy score is:', score)
# Out:
# The accuracy score is: 1.0

# %%
from sklearn import metrics
print('Accuracy:', metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 1.0

# %%
# Draw the confusion metrics
cm = metrics.confusion_matrix(y_test, predictions)
cm
# Out:
# array([[ 9,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0, 13]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt='.3f', linewidths= .5, square = True, cmap = 'Spectral');
plt.ylabel('Actual Output');
plt.xlabel('predicted Output');
all_sample_title = 'Accuracy Score: {0}' . format(score)
plt.title(all_sample_title, size=15);

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt='.3f', linewidths= .5, square = True, cmap = 'Spectral');
plt.ylabel('Actual Output');
plt.xlabel('predicted Output');
all_sample_title = 'Accuracy Score: {0}' . format(score)
plt.title(all_sample_title, size=10);

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100) 
model.fit(x,y)
model.predict([[6,4,5,3]])
# Out:
# C:\Users\malik zaheer abbas\AppData\Local\Temp\ipykernel_11876\2850175508.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# C:\Users\malik zaheer abbas\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['virginica'], dtype=object)

# %%
# accuracy test
score1 = model.score(x_test, y_test)
print('The accuracy score is:', score1)
# Out:
# The accuracy score is: 1.0

# %%
from sklearn import metrics
print('Accuracy:', metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 1.0

# %%
# Draw the confusion metrics
cm1 = metrics.confusion_matrix(y_test, predictions)
cm1
# Out:
# array([[ 9,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0, 13]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt='.3f', linewidths= .5, square = True, cmap = 'Spectral');
plt.ylabel('Actual Output');
plt.xlabel('predicted Output');
all_sample_title = 'Accuracy Score: {0}' . format(score1)
plt.title(all_sample_title, size=15);
